# %%
import pandas as pd
df = pd.read_csv("DUMMY DATA.csv")

# %%
df.head(6)
# Out:
#    SN NO     NAME SPECIALIZATION  MARKS  Unnamed: 4
# 0      1    NIDHI             BA     22         NaN
# 1      2  NIMISHA             BA     21         NaN
# 2      3   VIDHYA             BA     23         NaN
# 3      4    MARIA             BA     25         NaN
# 4      5   AGATHA      MARKETING     23         NaN
# 5      6   ROSHAN      MARKETING     20         NaN

# %%
df.shape
# Out:
# (12, 5)

# %%
df.tail()
# Out:
#     SN NO     NAME SPECIALIZATION  MARKS  Unnamed: 4
# 7       8   VISHNU             BA     20         NaN
# 8       9     JUDY      MARKEITNG     24         NaN
# 9      10    MEENU      MARKETING     20         NaN
# 10     11  SHITHIN        FINANCE     20         NaN
# 11     12   ASHWIN        FINANCE     21         NaN

# %%
df.loc[0:1]
# Out:
#    SN NO     NAME SPECIALIZATION  MARKS  Unnamed: 4
# 0      1    NIDHI             BA     22         NaN
# 1      2  NIMISHA             BA     21         NaN

# %%
df.iloc[4:5]
# Out:
#    SN NO    NAME SPECIALIZATION  MARKS  Unnamed: 4
# 4      5  AGATHA      MARKETING     23         NaN

# %%
df.iloc[0:1]
# Out:
#    SN NO   NAME SPECIALIZATION  MARKS  Unnamed: 4
# 0      1  NIDHI             BA     22         NaN

# %%
df.loc[5:10]
# Out:
#     SN NO     NAME SPECIALIZATION  MARKS  Unnamed: 4
# 5       6   ROSHAN      MARKETING     20         NaN
# 6       7     HARI      MARKETING     25         NaN
# 7       8   VISHNU             BA     20         NaN
# 8       9     JUDY      MARKEITNG     24         NaN
# 9      10    MEENU      MARKETING     20         NaN
# 10     11  SHITHIN        FINANCE     20         NaN

# %%
df.loc[7:8]
# Out:
#    SN NO    NAME SPECIALIZATION  MARKS  Unnamed: 4
# 7      8  VISHNU             BA     20         NaN
# 8      9    JUDY      MARKEITNG     24         NaN

# %%
df.describe()
# Out:
#            SN NO      MARKS  Unnamed: 4
# count  12.000000  12.000000         0.0
# mean    6.500000  22.000000         NaN
# std     3.605551   1.954017         NaN
# min     1.000000  20.000000         NaN
# 25%     3.750000  20.000000         NaN
# 50%     6.500000  21.500000         NaN
# 75%     9.250000  23.250000         NaN
# max    12.000000  25.000000         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SN NO           12 non-null     int64
#  1   NAME            12 non-null     object
#  2   SPECIALIZATION  12 non-null     object
#  3   MARKS           12 non-null     int64
#  4   Unnamed: 4      0 non-null      float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 612.0+ bytes
